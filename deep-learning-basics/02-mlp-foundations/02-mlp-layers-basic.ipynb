# %% [markdown]
# # 3-2 MLP 입력층·은닉층·출력층
#
# 강의 원문 대신 직접 작성하고 실행한 코드와 학습 메모를 정리했습니다.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# 필수 1. MLP 층별 shape 추적하기
batch_size = 4
input_dim = 6
hidden_dim = 3
output_dim = 2
x = torch.randn(batch_size, input_dim)
layer1 = nn.Linear(input_dim, hidden_dim)
layer2 = nn.Linear(hidden_dim, output_dim)

# TODO: hidden, logits를 계산해보세요.
hidden = layer1(x)
logits = layer2(hidden)
print('x:', x.shape, 'hidden:', hidden.shape, 'logits:', logits.shape)

assert logits.shape == (batch_size, output_dim)
# Out:
# x: torch.Size([4, 6]) hidden: torch.Size([4, 3]) logits: torch.Size([4, 2])

# %%
# 필수 2. hidden size를 바꾸면 parameter 수가 어떻게 달라질까요?
def count_params(model):
    return sum(p.numel() for p in model.parameters())

# TODO: hidden_dim=4인 MLP를 만들어 parameter 수를 출력해보세요.
model = nn.Sequential(nn.Linear(6, 4), nn.ReLU(), nn.Linear(4, 2))
print('parameter count:', count_params(model))

assert count_params(model) == (6*4+4) + (4*2+2)

#hidden size를 바꾸면 신경망이 더 복잡해지기 때문에 파라미터 수는 늘어난다.
# Out:
# parameter count: 38

# %%
# 심화 1. depth와 width 비교하기
# TODO: 1-hidden-layer 모델과 2-hidden-layer 모델의 parameter 수를 비교해보세요.
model_a = nn.Sequential(nn.Linear(6, 4), nn.ReLU(), nn.Linear(4, 2))
model_b = nn.Sequential(nn.Linear(6, 4), nn.ReLU(), nn.Linear(4, 4), nn.ReLU(), nn.Linear(4, 2))
print('model_a params:', count_params(model_a))
print('model_b params:', count_params(model_b))
# Out:
# model_a params: 38
# model_b params: 58
